# %%
def average(numbers):
    total=float(sum(numbers))
    return (total/len(numbers))

def get_average(student):
    hw=average(student["homework"])
    quiz=average(student["quizzes"])
    test=average(student["tests"])
    return (10/100*hw)+(30/100*quiz)+(60/100*test)
def get_letter_grade(score):
    score=float(score)
    if (score >= 90):
        return "A"
    elif (score >= 80):
        return "B"
    elif (score >= 70):
        return "C"
    elif (score >= 60):
        return "D"
    else:
        return "F"
def get_class_average(students):
    results = []
    for student in students:
        results.append(get_average(student))
    return (average(results))
lloyd = {
 "name": "Lloyd",
 "homework": [90.0,97.0,75.0,92.0],
 "quizzes": [88.0,40.0,94.0],
 "tests": [75.0,90.0]
}
alice = {
 "name": "Alice",
 "homework": [100.0, 92.0, 98.0, 100.0],
 "quizzes": [82.0, 83.0, 91.0],
 "tests": [89.0, 97.0]
}
tyler = {
 "name": "Tyler",
 "homework": [0.0, 87.0, 75.0, 22.0],
 "quizzes": [0.0, 75.0, 78.0],
 "tests": [100.0, 100.0]
}
students=[lloyd,alice,tyler]
for student in students:
    for key,value in student.items():
        print(f"{key.title()}:{value}")
    print()
print("letter grade of Lloyd is",get_letter_grade(get_average(lloyd)))
print("class average is",get_class_average(students))
print("letter grade for class average is",get_letter_grade(get_class_average(students)))
# Out:
# Name:Lloyd
# Homework:[90.0, 97.0, 75.0, 92.0]
# Quizzes:[88.0, 40.0, 94.0]
# Tests:[75.0, 90.0]
#
# Name:Alice
# Homework:[100.0, 92.0, 98.0, 100.0]
# Quizzes:[82.0, 83.0, 91.0]
# Tests:[89.0, 97.0]
#
# Name:Tyler
# Homework:[0.0, 87.0, 75.0, 22.0]
# Quizzes:[0.0, 75.0, 78.0]
# Tests:[100.0, 100.0]
#
# letter grade of Lloyd is B
# class average is 83.86666666666666
# letter grade for class average is B

# %%
course_num=("COP 2510","EGN 3000L","MAC 2281","MUH 3016", "PHY 2048")
course_name={
        course_num[0]:"Programming Concept",
        course_num[1]: 'Foundations of Engineering Lab',
        course_num[2]: 'Calculus I',
        course_num[3]: 'Survey of Jazz',
        course_num[4]: 'General Physics I',
    }
course_instructor={
    course_num[0] : "Z. Beasley",
    course_num[1] : "J. Anderson",
    course_num[2] : "A. Makaryus",
    course_num[3] : "A. Wilkins",
    course_num[4] : "G. Pradhan",
}
class_times = {
    course_num[0] : "MW 12:30pm - 1:45pm",
    course_num[1] : "TR 11:00am - 12:15pm",
    course_num[2] : "MW 9:30am - 10:45am",
    course_num[3] : "online asynchronous",
    course_num[4] : "TR 5:00pm - 6:15pm",
}
course_number = input("Enter a course number: ")
if course_number in course_num:
    print("The course details are: ")
    print(f"Course name: {course_name[course_number]}")
    print(f"Course instructor: {course_instructor[course_number]}")
    print(f"Class Times: {class_times[course_number]}")
else:
    print(f"{course_number} can't be found.")
# Out:
# The course details are:
# Course name: Programming Concept
# Course instructor: Z. Beasley
# Class Times: MW 12:30pm - 1:45pm

# %%
days=("sunday","monday","tuesday","wednesday","thursday","friday","saturday")
total=0
data=[]
minimum=10000000000000000000000000000000000
maximum=0
for day in days:
    sales=float(input(f"Enter the sales for {day}"))
    while sales<0:
        sales=float(input(f"Input was invalid. Re-enter the sales for {day}"))
    if sales>maximum:
        maximum=sales
    if sales<minimum:
        minimum=sales
    print (f"Enter the sales for {day}: ${sales}")    
    data.append(sales)
total=sum(data)
print(f"Total sales is: ${total}")
print (f"The minimum sales amount is ${minimum}"),print(f"The maximum sale amount is ${maximum}")
# Out:
# Enter the sales for sunday: $4.0
# Enter the sales for monday: $5.0
# Enter the sales for tuesday: $6.0
# Enter the sales for wednesday: $4.0
# Enter the sales for thursday: $3.0
# Enter the sales for friday: $2.0
# Enter the sales for saturday: $3.0
# Total sales is: $27.0
# The minimum sales amount is $2.0
# The maximum sale amount is $6.0
# (None, None)

# %%
morse_code=(' ','--..--','.-.-.-','..--..','-----','.----',
            '..---','...--','....-','.....','-....','--...',
            '---..','----.','.-','-...','-.-.','-..','.','..-.',
            '--.','. ...','. .','.---','-.-','.-..','--','-.',
            '---','.---.','--.-','.-.','...','-','..-','...-',
            '.--','-..-','-.--','--..')

ui=str(input("enter"))
ui=ui.upper()
ui=tuple(ui)
for i in ui:
    if i==' ':
        print(morse_code[0],end='')
    elif i==',':
        print(morse_code[1],end='')
    elif i=='.':
        print(morse_code[2],end='')
    elif i=='?':
        print(morse_code[3],end='')
    elif i=='0':
        print(morse_code[4],end='')
    elif i=='1':
        print(morse_code[5],end='')
    elif i=='2':
        print(morse_code[6],end='')
    elif i=='3':
        print(morse_code[7],end='')
    elif i=='4':
        print(morse_code[8],end='')
    elif i=='5':
        print(morse_code[9],end='')
    elif i=='6':
        print(morse_code[10],end='')
    elif i=='7':
        print(morse_code[11],end='')
    elif i=='8':
        print(morse_code[12],end='')
    elif i=='9':
        print(morse_code[13],end='')
    elif i=='A':
        print(morse_code[14],end='')
    elif i=='B':
        print(morse_code[15],end='')
    elif i=='C':
        print(morse_code[16],end='')
    elif i=='D':
        print(morse_code[17],end='')
    elif i=='E':
        print(morse_code[18],end='')
    elif i=='F':
        print(morse_code[19],end='')
    elif i=='G':
        print(morse_code[20],end='')
    elif i=='H':
        print(morse_code[21],end='')
    elif i=='I':
        print(morse_code[22],end='')
    elif i=='J':
        print(morse_code[23],end='')
    elif i=='K':
        print(morse_code[24],end='')
    elif i=='L':
        print(morse_code[25],end='')
    elif i=='M':
        print(morse_code[26],end='')
    elif i=='N':
        print(morse_code[27],end='')
    elif i=='O':
        print(morse_code[28],end='')
    elif i=='P':
        print(morse_code[29],end='')
    elif i=='Q':
        print(morse_code[30],end='')
    elif i=='R':
        print(morse_code[31],end='')
    elif i=='S':
        print(morse_code[32],end='')
    elif i=='T':
        print(morse_code[33],end='')
    elif i=='U':
        print(morse_code[34],end='')
    elif i=='V':
        print(morse_code[35],end='')
    elif i=='W':
        print(morse_code[36],end='')
    elif i=='X':
        print(morse_code[37],end='')
    elif i=='Y':
        print(morse_code[38],end='')
    elif i=='Z':
        print(morse_code[39],end='')
# Out:
# -.---.-----
